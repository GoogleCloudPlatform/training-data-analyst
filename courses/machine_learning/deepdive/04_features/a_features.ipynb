# %% [markdown]
# # Introduction to Feature Engineering

# %% [markdown]
# **Learning Objectives**
#   * Improve the accuracy of a model by using feature engineering
#   * Understand there's two places to do feature engineering in Tensorflow
#     1. In the input functions
#     2. Using the `tf.feature_column` module

# %% [markdown]
# We'll illustrate feature engineering using a new dataset and a new task.
#
# **Task**: To estimate the value of a house.
#
# **Dataset**: The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.

# %% [markdown]
# ## Set Up
# In this first cell, we'll load the necessary libraries.

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

print(tf.__version__)
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.12.0

# %% [markdown]
# Next, we'll load our data set.

# %%
df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=",")

# %% [markdown]
# ## Examine Data
#
# It's a good idea to get to know your data a little bit before you work with it. `df.head()` prints the first 5 rows of a dataframe.
#
# Note median_income is measure in 10s of thousands

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# It's also useful to understand the distribution of each column. `df.describe()` will calculate the count, mean, standard deviation, max, min, and various quantiles.

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# ## Create Training and Evaluation Datasets
#
# If your data is all in memory, a quick and easy way to create a train/evaluation split is using a random number generator. But be sure to seed the random generator so that you get the same split every time!

# %%
np.random.seed(seed=1) # to ensure reproducible split
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]

# %%
traindf.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  13612.000000  13612.000000        13612.000000  13612.000000
# mean    -119.553292     35.616189           28.665736   2632.034308
# std        2.002110      2.135425           12.594345   2163.255535
# min     -124.300000     32.540000            1.000000      8.000000
# 25%     -121.770000     33.930000           18.000000   1461.000000
# 50%     -118.480000     34.240000           29.000000   2117.500000
# 75%     -118.000000     37.710000           37.000000   3146.000000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms   population    households  median_income  \
# count    13612.000000  13612.00000  13612.000000   13612.000000
# mean       536.032912   1423.30025    498.113797       3.902213
# std        416.662192   1126.02708    379.281269       1.924587
# min          1.000000      3.00000      1.000000       0.499900
# 25%        296.000000    787.00000    281.000000       2.574275
# 50%        432.000000   1168.00000    408.000000       3.551900
# 75%        644.250000   1715.00000    602.000000       4.794750
# max       5471.000000  35682.00000   5189.000000      15.000100
#
#        median_house_value
# count        13612.000000
# mean        207986.538863
# std         116514.341708
# min          14999.000000
# 25%         119600.000000
# 50%         180800.000000
# 75%         266300.000000
# max         500001.000000

# %%
evaldf.describe()
# Out:
#          longitude     latitude  housing_median_age   total_rooms  \
# count  3388.000000  3388.000000         3388.000000   3388.000000
# mean   -119.597530    35.661526           28.282468   2690.390791
# std       2.017306     2.144947           12.554301   2245.478132
# min    -124.350000    32.550000            2.000000      2.000000
# 25%    -121.830000    33.930000           18.000000   1467.000000
# 50%    -118.580000    34.280000           28.000000   2171.500000
# 75%    -118.000000    37.740000           37.000000   3167.250000
# max    -114.610000    41.860000           52.000000  32627.000000
#
#        total_bedrooms    population   households  median_income  \
# count     3388.000000   3388.000000  3388.000000    3388.000000
# mean       552.982290   1454.779811   513.709563       3.808708
# std        440.201298   1231.504194   404.706736       1.839038
# min          2.000000      6.000000     2.000000       0.499900
# 25%        300.000000    796.000000   283.750000       2.539800
# 50%        441.000000   1160.000000   414.000000       3.515600
# 75%        667.000000   1756.250000   615.250000       4.667375
# max       6445.000000  28566.000000  6082.000000      15.000100
#
#        median_house_value
# count         3388.000000
# mean        204546.264168
# std         113802.453246
# min          22500.000000
# 25%         118800.000000
# 50%         178650.000000
# 75%         258825.000000
# max         500001.000000

# %% [markdown]
# ## Input Functions
# Read from Pandas dataframe. Same as 03_tensorflow/c_estimator.ipynb

# %%
LABEL_SCALE = 1
def train_input_fn(df, batch_size=128):
    #1. Convert dataframe into correct (features,label) format for Estimator API
    dataset = tf.data.Dataset.from_tensor_slices((dict(df), df['median_house_value']/LABEL_SCALE))
    
    #2. Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)
   
    return dataset

def eval_input_fn(df, batch_size=128):
    #1. Convert dataframe into correct (features,label) format for Estimator API
    dataset = tf.data.Dataset.from_tensor_slices((dict(df), df['median_house_value']/LABEL_SCALE))

    #2.Batch the examples.
    dataset = dataset.batch(batch_size)
   
    return dataset

# %% [markdown]
# ## Define Feature Columns
#
# Simply pass all features through unchanged using `tf.feature_column.numeric_column()`. No feature engineering.

# %%
feature_names = list(df.columns.values)[:-1] 
print(feature_names)
feat_cols = [tf.feature_column.numeric_column(feature_name)
             for feature_name in feature_names]
# Out:
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income']

# %% [markdown]
# ## Train and Evaluate
#
# Here we introduce two new customizations:
#
# 1. Setting Learning Rate
#    - Previously when using premade estimators we have accepted the default optimizer type and learning rate. However in practice we almost always want to tune our learning rate explicitly. To do so we specify the `optimizer` argument when initializing an estimator. We can specify any of the optimizers in the `tf.train` package such as [AdamOptimizer](https://www.tensorflow.org/api_docs/python/tf/train/AdamOptimizer) and [AdagradOptimizer](https://www.tensorflow.org/api_docs/python/tf/train/AdagradOptimizer). The first argument when initializing each is the learning rate.
#
#
# 2. Custom Evaluation Metric (RMSE)
#    - The default evaluation metric `average_loss` is MSE, but we want RMSE. Previously we just took the square root of the final `average_loss`. However it would be better if we could calculate RMSE not just at the end, but for every intermediate checkpoint and plot the change over time in TensorBoard. [`tf.contrib.estimator.add_metrics()`](https://www.tensorflow.org/api_docs/python/tf/contrib/estimator/add_metrics) allows us to do this. We wrap our estimator with it, and provide a custom evaluation function.

# %%
# Create estimator train and evaluate function
def train_and_evaluate(output_dir, num_train_steps, model_type, learning_rate=.001):
  if model_type == 'Linear':
    estimator = tf.estimator.LinearRegressor(
        model_dir = output_dir, 
        feature_columns = feat_cols,
        optimizer = tf.train.AdamOptimizer(learning_rate),
        config = tf.estimator.RunConfig(
          tf_random_seed=1, # for reproducibility
          save_checkpoints_steps=max(10,num_train_steps//10) # checkpoint every N steps
        )
    ) 
    
  elif model_type == 'DNN':
    estimator = tf.estimator.DNNRegressor(
        model_dir = output_dir, 
        feature_columns = feat_cols,
        hidden_units = [10,10],
        optimizer = tf.train.AdamOptimizer(learning_rate),
        config = tf.estimator.RunConfig(
          tf_random_seed=1, # for reproducibility
          save_checkpoints_steps=max(10,num_train_steps//10) # checkpoint every N steps
        )
    ) 
    
  else:
    print('Invalid Model Type: Use "Linear" or "DNN"')
    return
  
  # Add custom evaluation metric
  def my_rmse(labels, predictions):
    pred_values = tf.squeeze(tf.cast(predictions['predictions'],tf.float64),axis=-1)
    return {'rmse': tf.metrics.root_mean_squared_error(labels, pred_values)}
  estimator = tf.contrib.estimator.add_metrics(estimator, my_rmse)  
                                          
  train_spec = tf.estimator.TrainSpec(input_fn = lambda:train_input_fn(traindf), 
                                      max_steps = num_train_steps)
  eval_spec = tf.estimator.EvalSpec(input_fn = lambda:eval_input_fn(evaldf), 
                                    steps = None, 
                                    start_delay_secs = 1, # start evaluating after N seconds, 
                                    throttle_secs = 1)  # evaluate every N seconds
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
  return estimator

# %%
# Launch tensorboard
from google.datalab.ml import TensorBoard

OUTDIR = './trained_model'
TensorBoard().start(OUTDIR)
# Out:
# <p>TensorBoard was started successfully with pid 91396. Click <a href="/_proxy/51083/" target="_blank">here</a> to access it.</p>
# 91396

# %% [markdown]
# ## Results (w/o Feature Engineering)
# Steps: 20000, Batch Size: 128
# - Baseline (always predict mean)
#   - RMSE: 114K
# - Linear Regressor
#   - RMSE: 170K (LR: 0.001)
#   - RMSE: 75K (LR: 10)
# - DNN w/ hidden_units = [10,10]
#   - RMSE: 99K (LR: 0.001)
#   - RMSE: 68K (LR: 0.1)
#
# Note the reported RMSE is for the best evaluation checkpoint, not neccesarily the last one.
#
# You can see the importance of tuning learning rate. Using the default learning rate of 0.001 the linear regression model doesn't even beat our baseline. Intuitively it makes sense the we need a high learning rate because the average magnitude of our labels is 200,000 so we'll need large weights. Learning large weights with a step size of 0.001 would take a very long time.

# %%
# %%time
# Run the model
shutil.rmtree(OUTDIR, ignore_errors = True)
estimator = train_and_evaluate(OUTDIR, 20000,'Linkear',learning_rate=0.1)

# %% [markdown]
# ## Predict
# Let's see what the predicted values were for the records in our evaluation dataset.

# %%
predictions = estimator.predict(input_fn=lambda:eval_input_fn(evaldf))
for items in predictions:
  print(items)

# %% [markdown]
# # Introducing Feature Engineering
#
# Now we have a baseline RMSE of 68K without using feature engineering to beat.
#
# Here's where we apply our human intution to help out our model. What features might be useful in predicting housing price?
#
# Location comes to mind. We have latitude and longitude, but it's not in a very learnable format. Let's make a grid.
#
# Let's also divide by number of house hold
#
# ## TODO:
# 1. First just add number of house hold divide by features
# 2. Then just lat/lon grid
# 3. Then both

# %% [markdown]
# ## Training and Evaluation
#
# In this exercise, we'll be trying to predict `median_house_value` It will be our label (sometimes also called a target).
#
# We'll modify the feature_cols and input function to represent the features you want to use.
#
# We divide `total_rooms` by `households` to get `avg_rooms_per_house` which we excect to positively correlate with `median_house_value`.
#
# We also divide `population` by `total_rooms` to get `avg_persons_per_room` which we expect to negatively correlate with `median_house_value`.

# %%
def train_input_fn(df, batch_size=128):
    #1. Add engineered features
    df = add_more_features(df)
    
    #2. Convert dataframe into correct (features,label) format for Estimator API
    dataset = tf.data.Dataset.from_tensor_slices((dict(df), df['median_house_value']))
    
    #3. Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)
   
    return dataset

def eval_input_fn(df, batch_size=128):
    #1. Add engineered features
    df = add_more_features(df)
    
    #2. Convert dataframe into correct (features,label) format for Estimator API
    dataset = tf.data.Dataset.from_tensor_slices((dict(df), df['median_house_value']))

    #3.Batch the examples.
    dataset = dataset.batch(batch_size)
   
    return dataset

# %%
def add_more_features(df):
  df['avg_rooms_per_house'] = df['total_rooms'] / df['households'] #expect positive correlation
  df['avg_bedrooms_per_house'] = df['total_bedrooms'] / df['households'] 
  df['avg_persons_per_room'] = df['population'] / df['total_rooms'] #expect negative correlation
  return df

# %%
# Define your feature columns
bucketized_longitude = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('longitude'), boundaries = np.arange(-124, -114, 1).tolist())
bucketized_latitude = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'), boundaries = np.arange(32.0, 42, 1).tolist())
grid = tf.feature_column.crossed_column([bucketized_longitude,bucketized_latitude],200)

feat_cols = [
    tf.feature_column.numeric_column('housing_median_age'),
    tf.feature_column.numeric_column('longitude'),
    tf.feature_column.numeric_column('latitude'),
    #tf.feature_column.numeric_column('population'),
    tf.feature_column.embedding_column(bucketized_longitude,5),
    tf.feature_column.embedding_column(bucketized_latitude,5),
    tf.feature_column.embedding_column(grid,10),
    tf.feature_column.numeric_column('avg_bedrooms_per_house'),
    tf.feature_column.numeric_column('avg_rooms_per_house'),
    tf.feature_column.numeric_column('avg_persons_per_room'),
    tf.feature_column.numeric_column('median_income')
]

# %%
# Launch tensorboard
from google.datalab.ml import TensorBoard

OUTDIR = './trained_model'
TensorBoard().start(OUTDIR)
# Out:
# <p>TensorBoard was started successfully with pid 3409. Click <a href="/_proxy/42207/" target="_blank">here</a> to access it.</p>
# 3409

# %% [markdown]
# ## Results (w/ Feature Engineering)
#
# No improvement with just blah.
# Steps: 20000, Batch Size: 128, Dividing Features by block
# - Linear Regressor
#   - RMSE: 170K (LR: 0.001)
#   - RMSE: 75K (LR: 10)
# - DNN w/ hidden_units = [10,10]
#   - RMSE: 99K (LR: 0.001)
#   - RMSE: 68K (LR: 0.1)
#
# Note the reported RMSE is for the best evaluation checkpoint, not neccesarily the last one.
#
# You can see the importance of tuning learning rate. Using the default learning rate of 0.001 the linear regression model doesn't even beat our baseline. Intuitively it makes sense the we need a high learning rate because the average magnitude of our labels is 200,000 so we'll need large weights. Learning large weights with a step size of 0.001 would take a very long time.

# %%
# %%time
# Run the model
shutil.rmtree(OUTDIR, ignore_errors = True)

estimator = train_and_evaluate('./trained_model/linear_default', 20000,'Linear')
estimator = train_and_evaluate('./trained_model/linear_lr', 20000,'Linear',10)
estimator = train_and_evaluate('./trained_model/dnn_default', 20000,'DNN')
estimator = train_and_evaluate('./trained_model/dnn_lr', 20000,'DNN',0.1)
# Out:
# INFO:tensorflow:Using config: {'_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe11d265048>, '_task_id': 0, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_global_id_in_cluster': 0, '_eval_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_is_chief': True, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_num_worker_replicas': 1, '_protocol': None, '_tf_random_seed': 1, '_save_checkpoints_secs': None, '_device_fn': None, '_save_checkpoints_steps': 2000, '_task_type': 'worker', '_log_step_count_steps': 100, '_evaluation_master': '', '_train_distribute': None, '_save_summary_steps': 100, '_model_dir': './trained_model/linear_default', '_experimental_distribute': None}
# INFO:tensorflow:Using config: {'_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe11d265f98>, '_task_id': 0, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_global_id_in_cluster': 0, '_eval_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_is_chief': True, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_num_worker_replicas': 1, '_protocol': None, '_tf_random_seed': 1, '_save_checkpoints_secs': None, '_device_fn': None, '_save_checkpoints_steps': 2000, '_task_type': 'worker', '_log_step_count_steps': 100, '_evaluation_master': '', '_train_distribute': None, '_save_summary_steps': 100, '_model_dir': './trained_model/linear_default', '_experimental_distribute': None}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 2000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# /usr/local/envs/py3env/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/envs/py3env/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/envs/py3env/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:loss = 3202315700000.0, step = 1
# INFO:tensorflow:global_step/sec: 109.789
# INFO:tensorflow:loss = 8733471500000.0, step = 101 (0.913 sec)
# INFO:tensorflow:global_step/sec: 131.897
# INFO:tensorflow:loss = 10859849000000.0, step = 201 (0.759 sec)
# INFO:tensorflow:global_step/sec: 129.993
# INFO:tensorflow:loss = 8457152400000.0, step = 301 (0.769 sec)
# INFO:tensorflow:global_step/sec: 137.217
# INFO:tensorflow:loss = 7909246000000.0, step = 401 (0.728 sec)
# INFO:tensorflow:global_step/sec: 137.084
# INFO:tensorflow:loss = 4943359000000.0, step = 501 (0.729 sec)
# INFO:tensorflow:global_step/sec: 135.744
# INFO:tensorflow:loss = 2933652500000.0, step = 601 (0.737 sec)
# INFO:tensorflow:global_step/sec: 135.328
# INFO:tensorflow:loss = 4964733700000.0, step = 701 (0.739 sec)
# INFO:tensorflow:global_step/sec: 134.935
# INFO:tensorflow:loss = 6599773000000.0, step = 801 (0.741 sec)
# INFO:tensorflow:global_step/sec: 138.578
# INFO:tensorflow:loss = 11576024000000.0, step = 901 (0.726 sec)
# INFO:tensorflow:global_step/sec: 138.434
# INFO:tensorflow:loss = 10502328000000.0, step = 1001 (0.718 sec)
# INFO:tensorflow:global_step/sec: 145.482
# INFO:tensorflow:loss = 6755702500000.0, step = 1101 (0.690 sec)
# INFO:tensorflow:global_step/sec: 139.31
# INFO:tensorflow:loss = 5637336500000.0, step = 1201 (0.717 sec)
# INFO:tensorflow:global_step/sec: 147.08
# INFO:tensorflow:loss = 7782802000000.0, step = 1301 (0.677 sec)
# INFO:tensorflow:global_step/sec: 133.242
# INFO:tensorflow:loss = 7092925600000.0, step = 1401 (0.751 sec)
# INFO:tensorflow:global_step/sec: 138.109
# INFO:tensorflow:loss = 6067545000000.0, step = 1501 (0.727 sec)
# INFO:tensorflow:global_step/sec: 137.457
# INFO:tensorflow:loss = 5423584000000.0, step = 1601 (0.728 sec)
# INFO:tensorflow:global_step/sec: 140.327
# INFO:tensorflow:loss = 9139024000000.0, step = 1701 (0.712 sec)
# INFO:tensorflow:global_step/sec: 140.349
# INFO:tensorflow:loss = 8143813000000.0, step = 1801 (0.709 sec)
# INFO:tensorflow:global_step/sec: 139.475
# INFO:tensorflow:loss = 11949507000000.0, step = 1901 (0.721 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:06:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:06:51
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 54591713000.0, global_step = 2000, label/mean = 204546.2, loss = 6850249000000.0, prediction/mean = 470.45728, rmse = 233648.7
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: ./trained_model/linear_default/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 31.948
# INFO:tensorflow:loss = 10121241000000.0, step = 2001 (3.126 sec)
# INFO:tensorflow:global_step/sec: 152.867
# INFO:tensorflow:loss = 7489184600000.0, step = 2101 (0.655 sec)
# INFO:tensorflow:global_step/sec: 157.989
# INFO:tensorflow:loss = 4165437200000.0, step = 2201 (0.631 sec)
# INFO:tensorflow:global_step/sec: 159.477
# INFO:tensorflow:loss = 3507851600000.0, step = 2301 (0.627 sec)
# INFO:tensorflow:global_step/sec: 143.311
# INFO:tensorflow:loss = 5170489000000.0, step = 2401 (0.698 sec)
# INFO:tensorflow:global_step/sec: 139.1
# INFO:tensorflow:loss = 8436639000000.0, step = 2501 (0.721 sec)
# INFO:tensorflow:global_step/sec: 134.016
# INFO:tensorflow:loss = 10932374000000.0, step = 2601 (0.745 sec)
# INFO:tensorflow:global_step/sec: 151.766
# INFO:tensorflow:loss = 9352246000000.0, step = 2701 (0.659 sec)
# INFO:tensorflow:global_step/sec: 145.979
# INFO:tensorflow:loss = 5990520500000.0, step = 2801 (0.686 sec)
# INFO:tensorflow:global_step/sec: 150.607
# INFO:tensorflow:loss = 6556736000000.0, step = 2901 (0.663 sec)
# INFO:tensorflow:global_step/sec: 145.455
# INFO:tensorflow:loss = 7221171700000.0, step = 3001 (0.688 sec)
# INFO:tensorflow:global_step/sec: 141.08
# INFO:tensorflow:loss = 7866665700000.0, step = 3101 (0.708 sec)
# INFO:tensorflow:global_step/sec: 156.258
# INFO:tensorflow:loss = 4021152000000.0, step = 3201 (0.640 sec)
# INFO:tensorflow:global_step/sec: 155.533
# INFO:tensorflow:loss = 4834468600000.0, step = 3301 (0.643 sec)
# INFO:tensorflow:global_step/sec: 161.982
# INFO:tensorflow:loss = 9214831000000.0, step = 3401 (0.617 sec)
# INFO:tensorflow:global_step/sec: 152.336
# INFO:tensorflow:loss = 9686647000000.0, step = 3501 (0.657 sec)
# INFO:tensorflow:global_step/sec: 149.473
# INFO:tensorflow:loss = 7059665000000.0, step = 3601 (0.668 sec)
# INFO:tensorflow:global_step/sec: 147.871
# INFO:tensorflow:loss = 7869966600000.0, step = 3701 (0.677 sec)
# INFO:tensorflow:global_step/sec: 148.313
# INFO:tensorflow:loss = 5936161000000.0, step = 3801 (0.674 sec)
# INFO:tensorflow:global_step/sec: 150.637
# INFO:tensorflow:loss = 4137100000000.0, step = 3901 (0.664 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:07:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:07:07
# INFO:tensorflow:Saving dict for global step 4000: average_loss = 54340170000.0, global_step = 4000, label/mean = 204546.2, loss = 6818684700000.0, prediction/mean = 1078.5704, rmse = 233109.78
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: ./trained_model/linear_default/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 37.3354
# INFO:tensorflow:loss = 5290095300000.0, step = 4001 (2.678 sec)
# INFO:tensorflow:global_step/sec: 156.371
# INFO:tensorflow:loss = 4491752000000.0, step = 4101 (0.640 sec)
# INFO:tensorflow:global_step/sec: 161.036
# INFO:tensorflow:loss = 9724171000000.0, step = 4201 (0.620 sec)
# INFO:tensorflow:global_step/sec: 168.199
# INFO:tensorflow:loss = 11560219000000.0, step = 4301 (0.595 sec)
# INFO:tensorflow:global_step/sec: 156.25
# INFO:tensorflow:loss = 7298763000000.0, step = 4401 (0.640 sec)
# INFO:tensorflow:global_step/sec: 152.895
# INFO:tensorflow:loss = 6869368000000.0, step = 4501 (0.654 sec)
# INFO:tensorflow:global_step/sec: 149.963
# INFO:tensorflow:loss = 7212753000000.0, step = 4601 (0.666 sec)
# INFO:tensorflow:global_step/sec: 148.712
# INFO:tensorflow:loss = 8155557000000.0, step = 4701 (0.673 sec)
# INFO:tensorflow:global_step/sec: 148.469
# INFO:tensorflow:loss = 6580387000000.0, step = 4801 (0.675 sec)
# INFO:tensorflow:global_step/sec: 150.903
# INFO:tensorflow:loss = 4873652300000.0, step = 4901 (0.663 sec)
# INFO:tensorflow:global_step/sec: 149.079
# INFO:tensorflow:loss = 4270948600000.0, step = 5001 (0.669 sec)
# INFO:tensorflow:global_step/sec: 162.353
# INFO:tensorflow:loss = 9406652000000.0, step = 5101 (0.616 sec)
# INFO:tensorflow:global_step/sec: 155.664
# INFO:tensorflow:loss = 10048080000000.0, step = 5201 (0.645 sec)
# INFO:tensorflow:global_step/sec: 158.045
# INFO:tensorflow:loss = 9247011000000.0, step = 5301 (0.631 sec)
# INFO:tensorflow:global_step/sec: 157.699
# INFO:tensorflow:loss = 7708118000000.0, step = 5401 (0.634 sec)
# INFO:tensorflow:global_step/sec: 160.371
# INFO:tensorflow:loss = 6479213000000.0, step = 5501 (0.622 sec)
# INFO:tensorflow:global_step/sec: 156.179
# INFO:tensorflow:loss = 3046969000000.0, step = 5601 (0.640 sec)
# INFO:tensorflow:global_step/sec: 158.984
# INFO:tensorflow:loss = 4407028000000.0, step = 5701 (0.630 sec)
# INFO:tensorflow:global_step/sec: 151.24
# INFO:tensorflow:loss = 5951238000000.0, step = 5801 (0.661 sec)
# INFO:tensorflow:global_step/sec: 149.668
# INFO:tensorflow:loss = 10455095000000.0, step = 5901 (0.669 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:07:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:07:22
# INFO:tensorflow:Saving dict for global step 6000: average_loss = 54047910000.0, global_step = 6000, label/mean = 204546.2, loss = 6782012000000.0, prediction/mean = 1786.9614, rmse = 232482.06
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: ./trained_model/linear_default/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 35.1311
# INFO:tensorflow:loss = 12717591000000.0, step = 6001 (2.849 sec)
# INFO:tensorflow:global_step/sec: 155.594
# INFO:tensorflow:loss = 6210725600000.0, step = 6101 (0.641 sec)
# INFO:tensorflow:global_step/sec: 156.271
# INFO:tensorflow:loss = 6735292500000.0, step = 6201 (0.639 sec)
# INFO:tensorflow:global_step/sec: 150.903
# INFO:tensorflow:loss = 7390095700000.0, step = 6301 (0.664 sec)
# INFO:tensorflow:global_step/sec: 153.127
# INFO:tensorflow:loss = 6954091500000.0, step = 6401 (0.651 sec)
# INFO:tensorflow:global_step/sec: 149.442
# INFO:tensorflow:loss = 6322831500000.0, step = 6501 (0.669 sec)
# INFO:tensorflow:global_step/sec: 151.288
# INFO:tensorflow:loss = 4655731400000.0, step = 6601 (0.660 sec)
# INFO:tensorflow:global_step/sec: 153.01
# INFO:tensorflow:loss = 3828023800000.0, step = 6701 (0.654 sec)
# INFO:tensorflow:global_step/sec: 147.23
# INFO:tensorflow:loss = 8356010400000.0, step = 6801 (0.679 sec)
# INFO:tensorflow:global_step/sec: 149.076
# INFO:tensorflow:loss = 12005826000000.0, step = 6901 (0.671 sec)
# INFO:tensorflow:global_step/sec: 155.501
# INFO:tensorflow:loss = 9234026000000.0, step = 7001 (0.643 sec)
# INFO:tensorflow:global_step/sec: 154.569
# INFO:tensorflow:loss = 8370000000000.0, step = 7101 (0.647 sec)
# INFO:tensorflow:global_step/sec: 152.91
# INFO:tensorflow:loss = 5136048000000.0, step = 7201 (0.654 sec)
# INFO:tensorflow:global_step/sec: 154.605
# INFO:tensorflow:loss = 3091011700000.0, step = 7301 (0.648 sec)
# INFO:tensorflow:global_step/sec: 154.546
# INFO:tensorflow:loss = 4687778500000.0, step = 7401 (0.645 sec)
# INFO:tensorflow:global_step/sec: 153.068
# INFO:tensorflow:loss = 6726501000000.0, step = 7501 (0.655 sec)
# INFO:tensorflow:global_step/sec: 151.302
# INFO:tensorflow:loss = 10093730000000.0, step = 7601 (0.659 sec)
# INFO:tensorflow:global_step/sec: 147.576
# INFO:tensorflow:loss = 11367048000000.0, step = 7701 (0.680 sec)
# INFO:tensorflow:global_step/sec: 152.134
# INFO:tensorflow:loss = 5694987000000.0, step = 7801 (0.654 sec)
# INFO:tensorflow:global_step/sec: 153.57
# INFO:tensorflow:loss = 6535571000000.0, step = 7901 (0.651 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:07:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:07:37
# INFO:tensorflow:Saving dict for global step 8000: average_loss = 53718237000.0, global_step = 8000, label/mean = 204546.2, loss = 6740644500000.0, prediction/mean = 2588.511, rmse = 231771.95
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: ./trained_model/linear_default/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 34.4757
# INFO:tensorflow:loss = 7429335000000.0, step = 8001 (2.901 sec)
# INFO:tensorflow:global_step/sec: 150.779
# INFO:tensorflow:loss = 6439200000000.0, step = 8101 (0.666 sec)
# INFO:tensorflow:global_step/sec: 157.562
# INFO:tensorflow:loss = 7346535000000.0, step = 8201 (0.631 sec)
# INFO:tensorflow:global_step/sec: 162.984
# INFO:tensorflow:loss = 3768603000000.0, step = 8301 (0.614 sec)
# INFO:tensorflow:global_step/sec: 153.666
# INFO:tensorflow:loss = 9236785000000.0, step = 8401 (0.651 sec)
# INFO:tensorflow:global_step/sec: 156.214
# INFO:tensorflow:loss = 9281134000000.0, step = 8501 (0.640 sec)
# INFO:tensorflow:global_step/sec: 151.828
# INFO:tensorflow:loss = 10720623000000.0, step = 8601 (0.658 sec)
# INFO:tensorflow:global_step/sec: 153.541
# INFO:tensorflow:loss = 10793331000000.0, step = 8701 (0.653 sec)
# INFO:tensorflow:global_step/sec: 124.436
# INFO:tensorflow:loss = 7768527300000.0, step = 8801 (0.806 sec)
# INFO:tensorflow:global_step/sec: 148.012
# INFO:tensorflow:loss = 3829966300000.0, step = 8901 (0.673 sec)
# INFO:tensorflow:global_step/sec: 149.887
# INFO:tensorflow:loss = 3479043600000.0, step = 9001 (0.667 sec)
# INFO:tensorflow:global_step/sec: 151.486
# INFO:tensorflow:loss = 5980082400000.0, step = 9101 (0.660 sec)
# INFO:tensorflow:global_step/sec: 154.42
# INFO:tensorflow:loss = 7594322700000.0, step = 9201 (0.648 sec)
# INFO:tensorflow:global_step/sec: 152.257
# INFO:tensorflow:loss = 12744303000000.0, step = 9301 (0.657 sec)
# INFO:tensorflow:global_step/sec: 156.72
# INFO:tensorflow:loss = 9453937000000.0, step = 9401 (0.639 sec)
# INFO:tensorflow:global_step/sec: 147.472
# INFO:tensorflow:loss = 6257650000000.0, step = 9501 (0.677 sec)
# INFO:tensorflow:global_step/sec: 149.999
# INFO:tensorflow:loss = 6639314000000.0, step = 9601 (0.667 sec)
# INFO:tensorflow:global_step/sec: 138.381
# INFO:tensorflow:loss = 7869700000000.0, step = 9701 (0.723 sec)
# INFO:tensorflow:global_step/sec: 116.175
# INFO:tensorflow:loss = 7057552000000.0, step = 9801 (0.861 sec)
# INFO:tensorflow:global_step/sec: 137.929
# INFO:tensorflow:loss = 5903227000000.0, step = 9901 (0.725 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:07:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:07:53
# INFO:tensorflow:Saving dict for global step 10000: average_loss = 53352407000.0, global_step = 10000, label/mean = 204546.2, loss = 6694739400000.0, prediction/mean = 3481.0732, rmse = 230981.4
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: ./trained_model/linear_default/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 32.5368
# INFO:tensorflow:loss = 4529000000000.0, step = 10001 (3.072 sec)
# INFO:tensorflow:global_step/sec: 142.064
# INFO:tensorflow:loss = 9152196000000.0, step = 10101 (0.703 sec)
# INFO:tensorflow:global_step/sec: 139.481
# INFO:tensorflow:loss = 9307605000000.0, step = 10201 (0.722 sec)
# INFO:tensorflow:global_step/sec: 134.933
# INFO:tensorflow:loss = 8653511000000.0, step = 10301 (0.736 sec)
# INFO:tensorflow:global_step/sec: 131.739
# INFO:tensorflow:loss = 8265795600000.0, step = 10401 (0.759 sec)
# INFO:tensorflow:global_step/sec: 144.526
# INFO:tensorflow:loss = 7483928600000.0, step = 10501 (0.693 sec)
# INFO:tensorflow:global_step/sec: 130.378
# INFO:tensorflow:loss = 3448836500000.0, step = 10601 (0.767 sec)
# INFO:tensorflow:global_step/sec: 134.74
# INFO:tensorflow:loss = 4126708900000.0, step = 10701 (0.744 sec)
# INFO:tensorflow:global_step/sec: 133.948
# INFO:tensorflow:loss = 4534035300000.0, step = 10801 (0.744 sec)
# INFO:tensorflow:global_step/sec: 137.089
# INFO:tensorflow:loss = 7899542000000.0, step = 10901 (0.730 sec)
# INFO:tensorflow:global_step/sec: 140.621
# INFO:tensorflow:loss = 13000616000000.0, step = 11001 (0.710 sec)
# INFO:tensorflow:global_step/sec: 141.011
# INFO:tensorflow:loss = 6974488000000.0, step = 11101 (0.709 sec)
# INFO:tensorflow:global_step/sec: 131.289
# INFO:tensorflow:loss = 5827243000000.0, step = 11201 (0.763 sec)
# INFO:tensorflow:global_step/sec: 136.425
# INFO:tensorflow:loss = 6883742000000.0, step = 11301 (0.733 sec)
# INFO:tensorflow:global_step/sec: 133.74
# INFO:tensorflow:loss = 6713432300000.0, step = 11401 (0.747 sec)
# INFO:tensorflow:global_step/sec: 147.597
# INFO:tensorflow:loss = 7856056000000.0, step = 11501 (0.678 sec)
# INFO:tensorflow:global_step/sec: 146.116
# INFO:tensorflow:loss = 4670694000000.0, step = 11601 (0.685 sec)
# INFO:tensorflow:global_step/sec: 150.471
# INFO:tensorflow:loss = 4176750300000.0, step = 11701 (0.670 sec)
# INFO:tensorflow:global_step/sec: 126.311
# INFO:tensorflow:loss = 8909448000000.0, step = 11801 (0.787 sec)
# INFO:tensorflow:global_step/sec: 130.156
# INFO:tensorflow:loss = 11466189000000.0, step = 11901 (0.768 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:08:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:08:10
# INFO:tensorflow:Saving dict for global step 12000: average_loss = 52952605000.0, global_step = 12000, label/mean = 204546.2, loss = 6644571000000.0, prediction/mean = 4460.799, rmse = 230114.33
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: ./trained_model/linear_default/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 34.3222
# INFO:tensorflow:loss = 7908804300000.0, step = 12001 (2.914 sec)
# INFO:tensorflow:global_step/sec: 135.066
# INFO:tensorflow:loss = 9175322000000.0, step = 12101 (0.745 sec)
# INFO:tensorflow:global_step/sec: 129.05
# INFO:tensorflow:loss = 6376843600000.0, step = 12201 (0.772 sec)
# INFO:tensorflow:global_step/sec: 137.568
# INFO:tensorflow:loss = 2834066300000.0, step = 12301 (0.725 sec)
# INFO:tensorflow:global_step/sec: 132.686
# INFO:tensorflow:loss = 4298494700000.0, step = 12401 (0.754 sec)
# INFO:tensorflow:global_step/sec: 134.985
# INFO:tensorflow:loss = 7096971000000.0, step = 12501 (0.740 sec)
# INFO:tensorflow:global_step/sec: 140.025
# INFO:tensorflow:loss = 8286342000000.0, step = 12601 (0.714 sec)
# INFO:tensorflow:global_step/sec: 136.559
# INFO:tensorflow:loss = 10496296000000.0, step = 12701 (0.732 sec)
# INFO:tensorflow:global_step/sec: 139.758
# INFO:tensorflow:loss = 6889140000000.0, step = 12801 (0.716 sec)
# INFO:tensorflow:global_step/sec: 133.511
# INFO:tensorflow:loss = 5657300000000.0, step = 12901 (0.749 sec)
# INFO:tensorflow:global_step/sec: 142.84
# INFO:tensorflow:loss = 7919203500000.0, step = 13001 (0.701 sec)
# INFO:tensorflow:global_step/sec: 145.75
# INFO:tensorflow:loss = 6757707400000.0, step = 13101 (0.687 sec)
# INFO:tensorflow:global_step/sec: 150.479
# INFO:tensorflow:loss = 7591076000000.0, step = 13201 (0.663 sec)
# INFO:tensorflow:global_step/sec: 149.151
# INFO:tensorflow:loss = 3716556800000.0, step = 13301 (0.674 sec)
# INFO:tensorflow:global_step/sec: 158.385
# INFO:tensorflow:loss = 3928115600000.0, step = 13401 (0.628 sec)
# INFO:tensorflow:global_step/sec: 157.954
# INFO:tensorflow:loss = 9114428000000.0, step = 13501 (0.633 sec)
# INFO:tensorflow:global_step/sec: 157.639
# INFO:tensorflow:loss = 10674384000000.0, step = 13601 (0.634 sec)
# INFO:tensorflow:global_step/sec: 155.564
# INFO:tensorflow:loss = 8305400000000.0, step = 13701 (0.642 sec)
# INFO:tensorflow:global_step/sec: 154.915
# INFO:tensorflow:loss = 7679786400000.0, step = 13801 (0.646 sec)
# INFO:tensorflow:global_step/sec: 150.64
# INFO:tensorflow:loss = 4093094400000.0, step = 13901 (0.664 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:08:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:08:26
# INFO:tensorflow:Saving dict for global step 14000: average_loss = 52518285000.0, global_step = 14000, label/mean = 204546.2, loss = 6590072600000.0, prediction/mean = 5529.536, rmse = 229168.69
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: ./trained_model/linear_default/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 35.5902
# INFO:tensorflow:loss = 3468224400000.0, step = 14001 (2.810 sec)
# INFO:tensorflow:global_step/sec: 150.624
# INFO:tensorflow:loss = 4266088500000.0, step = 14101 (0.667 sec)
# INFO:tensorflow:global_step/sec: 148.632
# INFO:tensorflow:loss = 6110174500000.0, step = 14201 (0.669 sec)
# INFO:tensorflow:global_step/sec: 152.718
# INFO:tensorflow:loss = 9115194000000.0, step = 14301 (0.655 sec)
# INFO:tensorflow:global_step/sec: 152.61
# INFO:tensorflow:loss = 9480103000000.0, step = 14401 (0.655 sec)
# INFO:tensorflow:global_step/sec: 151.265
# INFO:tensorflow:loss = 7148780000000.0, step = 14501 (0.661 sec)
# INFO:tensorflow:global_step/sec: 155.018
# INFO:tensorflow:loss = 6641120400000.0, step = 14601 (0.645 sec)
# INFO:tensorflow:global_step/sec: 151.719
# INFO:tensorflow:loss = 7548266600000.0, step = 14701 (0.660 sec)
# INFO:tensorflow:global_step/sec: 152.529
# INFO:tensorflow:loss = 7138351000000.0, step = 14801 (0.655 sec)
# INFO:tensorflow:global_step/sec: 148.458
# INFO:tensorflow:loss = 7553047600000.0, step = 14901 (0.685 sec)
# INFO:tensorflow:global_step/sec: 146.547
# INFO:tensorflow:loss = 3942957400000.0, step = 15001 (0.671 sec)
# INFO:tensorflow:global_step/sec: 141.432
# INFO:tensorflow:loss = 6973755000000.0, step = 15101 (0.707 sec)
# INFO:tensorflow:global_step/sec: 144.931
# INFO:tensorflow:loss = 9953947000000.0, step = 15201 (0.690 sec)
# INFO:tensorflow:global_step/sec: 138.721
# INFO:tensorflow:loss = 10159294000000.0, step = 15301 (0.720 sec)
# INFO:tensorflow:global_step/sec: 145.266
# INFO:tensorflow:loss = 8502818400000.0, step = 15401 (0.691 sec)
# INFO:tensorflow:global_step/sec: 125.3
# INFO:tensorflow:loss = 7206801000000.0, step = 15501 (0.797 sec)
# INFO:tensorflow:global_step/sec: 146.568
# INFO:tensorflow:loss = 3938145800000.0, step = 15601 (0.683 sec)
# INFO:tensorflow:global_step/sec: 120.358
# INFO:tensorflow:loss = 3896468300000.0, step = 15701 (0.829 sec)
# INFO:tensorflow:global_step/sec: 145.78
# INFO:tensorflow:loss = 4825728700000.0, step = 15801 (0.685 sec)
# INFO:tensorflow:global_step/sec: 164.103
# INFO:tensorflow:loss = 8654069700000.0, step = 15901 (0.611 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:08:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:08:42
# INFO:tensorflow:Saving dict for global step 16000: average_loss = 52052480000.0, global_step = 16000, label/mean = 204546.2, loss = 6531622400000.0, prediction/mean = 6682.2715, rmse = 228150.12
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: ./trained_model/linear_default/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 37.5927
# INFO:tensorflow:loss = 11271592000000.0, step = 16001 (2.659 sec)
# INFO:tensorflow:global_step/sec: 127.46
# INFO:tensorflow:loss = 11323197000000.0, step = 16101 (0.790 sec)
# INFO:tensorflow:global_step/sec: 139.295
# INFO:tensorflow:loss = 6519431000000.0, step = 16201 (0.712 sec)
# INFO:tensorflow:global_step/sec: 149.07
# INFO:tensorflow:loss = 4931880000000.0, step = 16301 (0.676 sec)
# INFO:tensorflow:global_step/sec: 138.751
# INFO:tensorflow:loss = 6788138000000.0, step = 16401 (0.718 sec)
# INFO:tensorflow:global_step/sec: 119.716
# INFO:tensorflow:loss = 6993227000000.0, step = 16501 (0.835 sec)
# INFO:tensorflow:global_step/sec: 138.455
# INFO:tensorflow:loss = 6021540000000.0, step = 16601 (0.721 sec)
# INFO:tensorflow:global_step/sec: 142.591
# INFO:tensorflow:loss = 5651534000000.0, step = 16701 (0.700 sec)
# INFO:tensorflow:global_step/sec: 152.074
# INFO:tensorflow:loss = 7145743500000.0, step = 16801 (0.659 sec)
# INFO:tensorflow:global_step/sec: 149.679
# INFO:tensorflow:loss = 7981561300000.0, step = 16901 (0.667 sec)
# INFO:tensorflow:global_step/sec: 144.163
# INFO:tensorflow:loss = 8506992000000.0, step = 17001 (0.693 sec)
# INFO:tensorflow:global_step/sec: 150.381
# INFO:tensorflow:loss = 8701414000000.0, step = 17101 (0.665 sec)
# INFO:tensorflow:global_step/sec: 149.038
# INFO:tensorflow:loss = 7259306300000.0, step = 17201 (0.671 sec)
# INFO:tensorflow:global_step/sec: 128.04
# INFO:tensorflow:loss = 3603578700000.0, step = 17301 (0.781 sec)
# INFO:tensorflow:global_step/sec: 120.36
# INFO:tensorflow:loss = 3460382900000.0, step = 17401 (0.831 sec)
# INFO:tensorflow:global_step/sec: 125.888
# INFO:tensorflow:loss = 3705800000000.0, step = 17501 (0.798 sec)
# INFO:tensorflow:global_step/sec: 107.64
# INFO:tensorflow:loss = 8343878000000.0, step = 17601 (0.927 sec)
# INFO:tensorflow:global_step/sec: 105.203
# INFO:tensorflow:loss = 10712004000000.0, step = 17701 (0.949 sec)
# INFO:tensorflow:global_step/sec: 123.884
# INFO:tensorflow:loss = 8775629500000.0, step = 17801 (0.808 sec)
# INFO:tensorflow:global_step/sec: 133.075
# INFO:tensorflow:loss = 6626756000000.0, step = 17901 (0.755 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:08:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:09:00
# INFO:tensorflow:Saving dict for global step 18000: average_loss = 51554870000.0, global_step = 18000, label/mean = 204546.2, loss = 6469181000000.0, prediction/mean = 7920.9966, rmse = 227056.97
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: ./trained_model/linear_default/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 27.446
# INFO:tensorflow:loss = 6876242600000.0, step = 18001 (3.640 sec)
# INFO:tensorflow:global_step/sec: 116.508
# INFO:tensorflow:loss = 6774136500000.0, step = 18101 (0.860 sec)
# INFO:tensorflow:global_step/sec: 121.77
# INFO:tensorflow:loss = 6188910500000.0, step = 18201 (0.820 sec)
# INFO:tensorflow:global_step/sec: 123.765
# INFO:tensorflow:loss = 4968665000000.0, step = 18301 (0.812 sec)
# INFO:tensorflow:global_step/sec: 135.494
# INFO:tensorflow:loss = 3709913300000.0, step = 18401 (0.736 sec)
# INFO:tensorflow:global_step/sec: 100.499
# INFO:tensorflow:loss = 7308365000000.0, step = 18501 (0.997 sec)
# INFO:tensorflow:global_step/sec: 107.88
# INFO:tensorflow:loss = 9375577000000.0, step = 18601 (0.927 sec)
# INFO:tensorflow:global_step/sec: 109.584
# INFO:tensorflow:loss = 7963571000000.0, step = 18701 (0.913 sec)
# INFO:tensorflow:global_step/sec: 114.557
# INFO:tensorflow:loss = 8534354300000.0, step = 18801 (0.870 sec)
# INFO:tensorflow:global_step/sec: 130.227
# INFO:tensorflow:loss = 5325424400000.0, step = 18901 (0.767 sec)
# INFO:tensorflow:global_step/sec: 112.023
# INFO:tensorflow:loss = 3516575800000.0, step = 19001 (0.893 sec)
# INFO:tensorflow:global_step/sec: 139.266
# INFO:tensorflow:loss = 3487311000000.0, step = 19101 (0.719 sec)
# INFO:tensorflow:global_step/sec: 113.24
# INFO:tensorflow:loss = 4717783500000.0, step = 19201 (0.883 sec)
# INFO:tensorflow:global_step/sec: 125.855
# INFO:tensorflow:loss = 8632313000000.0, step = 19301 (0.795 sec)
# INFO:tensorflow:global_step/sec: 116.303
# INFO:tensorflow:loss = 11036703000000.0, step = 19401 (0.860 sec)
# INFO:tensorflow:global_step/sec: 112.006
# INFO:tensorflow:loss = 7019222300000.0, step = 19501 (0.896 sec)
# INFO:tensorflow:global_step/sec: 118.477
# INFO:tensorflow:loss = 5243569000000.0, step = 19601 (0.843 sec)
# INFO:tensorflow:global_step/sec: 119.596
# INFO:tensorflow:loss = 7318029000000.0, step = 19701 (0.833 sec)
# INFO:tensorflow:global_step/sec: 147.533
# INFO:tensorflow:loss = 6727388000000.0, step = 19801 (0.678 sec)
# INFO:tensorflow:global_step/sec: 58.6996
# INFO:tensorflow:loss = 7859860400000.0, step = 19901 (1.704 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./trained_model/linear_default/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:09:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_default/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:09:19
# INFO:tensorflow:Saving dict for global step 20000: average_loss = 51025240000.0, global_step = 20000, label/mean = 204546.2, loss = 6402722500000.0, prediction/mean = 9247.248, rmse = 225887.67
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./trained_model/linear_default/model.ckpt-20000
# INFO:tensorflow:Loss for final step: 3825468700000.0.
# INFO:tensorflow:Using config: {'_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe11053c400>, '_task_id': 0, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_global_id_in_cluster': 0, '_eval_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_is_chief': True, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_num_worker_replicas': 1, '_protocol': None, '_tf_random_seed': 1, '_save_checkpoints_secs': None, '_device_fn': None, '_save_checkpoints_steps': 2000, '_task_type': 'worker', '_log_step_count_steps': 100, '_evaluation_master': '', '_train_distribute': None, '_save_summary_steps': 100, '_model_dir': './trained_model/linear_lr', '_experimental_distribute': None}
# INFO:tensorflow:Using config: {'_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe11936c0b8>, '_task_id': 0, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_global_id_in_cluster': 0, '_eval_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_is_chief': True, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_num_worker_replicas': 1, '_protocol': None, '_tf_random_seed': 1, '_save_checkpoints_secs': None, '_device_fn': None, '_save_checkpoints_steps': 2000, '_task_type': 'worker', '_log_step_count_steps': 100, '_evaluation_master': '', '_train_distribute': None, '_save_summary_steps': 100, '_model_dir': './trained_model/linear_lr', '_experimental_distribute': None}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 2000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_model/linear_lr/model.ckpt.
# INFO:tensorflow:loss = 3202315700000.0, step = 1
# INFO:tensorflow:global_step/sec: 94.1801
# INFO:tensorflow:loss = 1592975400000.0, step = 101 (1.068 sec)
# INFO:tensorflow:global_step/sec: 123.964
# INFO:tensorflow:loss = 1866166800000.0, step = 201 (0.804 sec)
# INFO:tensorflow:global_step/sec: 145.363
# INFO:tensorflow:loss = 1430511200000.0, step = 301 (0.695 sec)
# INFO:tensorflow:global_step/sec: 132.181
# INFO:tensorflow:loss = 1262571000000.0, step = 401 (0.751 sec)
# INFO:tensorflow:global_step/sec: 143.95
# INFO:tensorflow:loss = 874754200000.0, step = 501 (0.693 sec)
# INFO:tensorflow:global_step/sec: 151.14
# INFO:tensorflow:loss = 622370200000.0, step = 601 (0.663 sec)
# INFO:tensorflow:global_step/sec: 152.412
# INFO:tensorflow:loss = 764148840000.0, step = 701 (0.655 sec)
# INFO:tensorflow:global_step/sec: 114.88
# INFO:tensorflow:loss = 829398840000.0, step = 801 (0.871 sec)
# INFO:tensorflow:global_step/sec: 130.107
# INFO:tensorflow:loss = 1365506800000.0, step = 901 (0.771 sec)
# INFO:tensorflow:global_step/sec: 134.322
# INFO:tensorflow:loss = 1546966000000.0, step = 1001 (0.742 sec)
# INFO:tensorflow:global_step/sec: 151.438
# INFO:tensorflow:loss = 1252975200000.0, step = 1101 (0.660 sec)
# INFO:tensorflow:global_step/sec: 157.876
# INFO:tensorflow:loss = 682463100000.0, step = 1201 (0.635 sec)
# INFO:tensorflow:global_step/sec: 153.111
# INFO:tensorflow:loss = 949049500000.0, step = 1301 (0.652 sec)
# INFO:tensorflow:global_step/sec: 147.946
# INFO:tensorflow:loss = 1037055560000.0, step = 1401 (0.676 sec)
# INFO:tensorflow:global_step/sec: 129.759
# INFO:tensorflow:loss = 906072300000.0, step = 1501 (0.771 sec)
# INFO:tensorflow:global_step/sec: 138.368
# INFO:tensorflow:loss = 978618160000.0, step = 1601 (0.722 sec)
# INFO:tensorflow:global_step/sec: 134.075
# INFO:tensorflow:loss = 803379000000.0, step = 1701 (0.750 sec)
# INFO:tensorflow:global_step/sec: 131.743
# INFO:tensorflow:loss = 843360900000.0, step = 1801 (0.756 sec)
# INFO:tensorflow:global_step/sec: 159.762
# INFO:tensorflow:loss = 1582784800000.0, step = 1901 (0.625 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ./trained_model/linear_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:09:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_lr/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:09:40
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 8077620000.0, global_step = 2000, label/mean = 204546.2, loss = 1013591800000.0, prediction/mean = 233865.4, rmse = 89875.58
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: ./trained_model/linear_lr/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 36.5259
# INFO:tensorflow:loss = 1201541700000.0, step = 2001 (2.738 sec)
# INFO:tensorflow:global_step/sec: 123.116
# INFO:tensorflow:loss = 645406700000.0, step = 2101 (0.817 sec)
# INFO:tensorflow:global_step/sec: 121.201
# INFO:tensorflow:loss = 563077700000.0, step = 2201 (0.821 sec)
# INFO:tensorflow:global_step/sec: 136.399
# INFO:tensorflow:loss = 505101420000.0, step = 2301 (0.732 sec)
# INFO:tensorflow:global_step/sec: 120.512
# INFO:tensorflow:loss = 767039640000.0, step = 2401 (0.830 sec)
# INFO:tensorflow:global_step/sec: 163.009
# INFO:tensorflow:loss = 814265800000.0, step = 2501 (0.616 sec)
# INFO:tensorflow:global_step/sec: 159.969
# INFO:tensorflow:loss = 1337070700000.0, step = 2601 (0.623 sec)
# INFO:tensorflow:global_step/sec: 165.889
# INFO:tensorflow:loss = 1040769350000.0, step = 2701 (0.606 sec)
# INFO:tensorflow:global_step/sec: 164.771
# INFO:tensorflow:loss = 626859050000.0, step = 2801 (0.606 sec)
# INFO:tensorflow:global_step/sec: 170.651
# INFO:tensorflow:loss = 451123580000.0, step = 2901 (0.583 sec)
# INFO:tensorflow:global_step/sec: 167.446
# INFO:tensorflow:loss = 783139860000.0, step = 3001 (0.597 sec)
# INFO:tensorflow:global_step/sec: 161.807
# INFO:tensorflow:loss = 894769560000.0, step = 3101 (0.620 sec)
# INFO:tensorflow:global_step/sec: 163.485
# INFO:tensorflow:loss = 330606440000.0, step = 3201 (0.618 sec)
# INFO:tensorflow:global_step/sec: 161.38
# INFO:tensorflow:loss = 486512360000.0, step = 3301 (0.612 sec)
# INFO:tensorflow:global_step/sec: 163.375
# INFO:tensorflow:loss = 839352250000.0, step = 3401 (0.612 sec)
# INFO:tensorflow:global_step/sec: 158.765
# INFO:tensorflow:loss = 864210000000.0, step = 3501 (0.633 sec)
# INFO:tensorflow:global_step/sec: 161.771
# INFO:tensorflow:loss = 852080200000.0, step = 3601 (0.615 sec)
# INFO:tensorflow:global_step/sec: 160.975
# INFO:tensorflow:loss = 762630100000.0, step = 3701 (0.621 sec)
# INFO:tensorflow:global_step/sec: 156.484
# INFO:tensorflow:loss = 403995000000.0, step = 3801 (0.639 sec)
# INFO:tensorflow:global_step/sec: 165.64
# INFO:tensorflow:loss = 547099870000.0, step = 3901 (0.604 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into ./trained_model/linear_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:09:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_lr/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:09:55
# INFO:tensorflow:Saving dict for global step 4000: average_loss = 5780862000.0, global_step = 4000, label/mean = 204546.2, loss = 725391100000.0, prediction/mean = 204473.56, rmse = 76031.98
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: ./trained_model/linear_lr/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 39.3887
# INFO:tensorflow:loss = 631766400000.0, step = 4001 (2.539 sec)
# INFO:tensorflow:global_step/sec: 145.191
# INFO:tensorflow:loss = 837283500000.0, step = 4101 (0.688 sec)
# INFO:tensorflow:global_step/sec: 161.755
# INFO:tensorflow:loss = 979108360000.0, step = 4201 (0.619 sec)
# INFO:tensorflow:global_step/sec: 131.363
# INFO:tensorflow:loss = 1233590200000.0, step = 4301 (0.761 sec)
# INFO:tensorflow:global_step/sec: 132.131
# INFO:tensorflow:loss = 637644240000.0, step = 4401 (0.757 sec)
# INFO:tensorflow:global_step/sec: 135.136
# INFO:tensorflow:loss = 929408400000.0, step = 4501 (0.740 sec)
# INFO:tensorflow:global_step/sec: 144.272
# INFO:tensorflow:loss = 751848000000.0, step = 4601 (0.692 sec)
# INFO:tensorflow:global_step/sec: 146.559
# INFO:tensorflow:loss = 641461060000.0, step = 4701 (0.683 sec)
# INFO:tensorflow:global_step/sec: 165.891
# INFO:tensorflow:loss = 486616860000.0, step = 4801 (0.602 sec)
# INFO:tensorflow:global_step/sec: 168.998
# INFO:tensorflow:loss = 740546100000.0, step = 4901 (0.592 sec)
# INFO:tensorflow:global_step/sec: 166.783
# INFO:tensorflow:loss = 455869730000.0, step = 5001 (0.599 sec)
# INFO:tensorflow:global_step/sec: 169.767
# INFO:tensorflow:loss = 573335300000.0, step = 5101 (0.589 sec)
# INFO:tensorflow:global_step/sec: 168.567
# INFO:tensorflow:loss = 788505950000.0, step = 5201 (0.594 sec)
# INFO:tensorflow:global_step/sec: 168.603
# INFO:tensorflow:loss = 823794700000.0, step = 5301 (0.596 sec)
# INFO:tensorflow:global_step/sec: 173.493
# INFO:tensorflow:loss = 651241700000.0, step = 5401 (0.573 sec)
# INFO:tensorflow:global_step/sec: 172.853
# INFO:tensorflow:loss = 743619560000.0, step = 5501 (0.579 sec)
# INFO:tensorflow:global_step/sec: 161.25
# INFO:tensorflow:loss = 323198000000.0, step = 5601 (0.620 sec)
# INFO:tensorflow:global_step/sec: 167.677
# INFO:tensorflow:loss = 537331760000.0, step = 5701 (0.596 sec)
# INFO:tensorflow:global_step/sec: 165.144
# INFO:tensorflow:loss = 673148800000.0, step = 5801 (0.606 sec)
# INFO:tensorflow:global_step/sec: 163.572
# INFO:tensorflow:loss = 1082832100000.0, step = 5901 (0.613 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into ./trained_model/linear_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:10:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_lr/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:10:10
# INFO:tensorflow:Saving dict for global step 6000: average_loss = 5983794000.0, global_step = 6000, label/mean = 204546.2, loss = 750855400000.0, prediction/mean = 231686.1, rmse = 77354.984
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: ./trained_model/linear_lr/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 41.8673
# INFO:tensorflow:loss = 1199964400000.0, step = 6001 (2.387 sec)
# INFO:tensorflow:global_step/sec: 163.283
# INFO:tensorflow:loss = 611143300000.0, step = 6101 (0.613 sec)
# INFO:tensorflow:global_step/sec: 157.759
# INFO:tensorflow:loss = 624837100000.0, step = 6201 (0.633 sec)
# INFO:tensorflow:global_step/sec: 164.606
# INFO:tensorflow:loss = 601607000000.0, step = 6301 (0.607 sec)
# INFO:tensorflow:global_step/sec: 172.89
# INFO:tensorflow:loss = 504669500000.0, step = 6401 (0.579 sec)
# INFO:tensorflow:global_step/sec: 167.128
# INFO:tensorflow:loss = 620628300000.0, step = 6501 (0.598 sec)
# INFO:tensorflow:global_step/sec: 139.435
# INFO:tensorflow:loss = 623436900000.0, step = 6601 (0.720 sec)
# INFO:tensorflow:global_step/sec: 166.081
# INFO:tensorflow:loss = 432788900000.0, step = 6701 (0.598 sec)
# INFO:tensorflow:global_step/sec: 167.597
# INFO:tensorflow:loss = 645890100000.0, step = 6801 (0.597 sec)
# INFO:tensorflow:global_step/sec: 169.281
# INFO:tensorflow:loss = 1113112200000.0, step = 6901 (0.591 sec)
# INFO:tensorflow:global_step/sec: 165.568
# INFO:tensorflow:loss = 632978540000.0, step = 7001 (0.604 sec)
# INFO:tensorflow:global_step/sec: 168.506
# INFO:tensorflow:loss = 686364160000.0, step = 7101 (0.597 sec)
# INFO:tensorflow:global_step/sec: 170.982
# INFO:tensorflow:loss = 391817530000.0, step = 7201 (0.582 sec)
# INFO:tensorflow:global_step/sec: 166.91
# INFO:tensorflow:loss = 279029900000.0, step = 7301 (0.599 sec)
# INFO:tensorflow:global_step/sec: 145.805
# INFO:tensorflow:loss = 465486770000.0, step = 7401 (0.689 sec)
# INFO:tensorflow:global_step/sec: 162.56
# INFO:tensorflow:loss = 504709940000.0, step = 7501 (0.613 sec)
# INFO:tensorflow:global_step/sec: 163.986
# INFO:tensorflow:loss = 1051341900000.0, step = 7601 (0.610 sec)
# INFO:tensorflow:global_step/sec: 165.022
# INFO:tensorflow:loss = 1092484100000.0, step = 7701 (0.608 sec)
# INFO:tensorflow:global_step/sec: 159.434
# INFO:tensorflow:loss = 733103200000.0, step = 7801 (0.624 sec)
# INFO:tensorflow:global_step/sec: 171.485
# INFO:tensorflow:loss = 541925500000.0, step = 7901 (0.587 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into ./trained_model/linear_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:10:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/linear_lr/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:10:24
# INFO:tensorflow:Saving dict for global step 8000: average_loss = 5305029600.0, global_step = 8000, label/mean = 204546.2, loss = 665683000000.0, prediction/mean = 206237.23, rmse = 72835.63
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: ./trained_model/linear_lr/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 41.2412
# INFO:tensorflow:loss = 553727600000.0, step = 8001 (2.421 sec)
# INFO:tensorflow:global_step/sec: 164.467
# INFO:tensorflow:loss = 302978240000.0, step = 8101 (0.612 sec)
# INFO:tensorflow:global_step/sec: 167.106
# INFO:tensorflow:loss = 657599230000.0, step = 8201 (0.594 sec)
# INFO:tensorflow:global_step/sec: 167.2
# INFO:tensorflow:loss = 549399070000.0, step = 8301 (0.601 sec)
# INFO:tensorflow:global_step/sec: 165.464
# ...
# INFO:tensorflow:global_step/sec: 119.73
# INFO:tensorflow:loss = 539213630000.0, step = 9801 (0.836 sec)
# INFO:tensorflow:global_step/sec: 129.698
# INFO:tensorflow:loss = 581646200000.0, step = 9901 (0.770 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./trained_model/dnn_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:15:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/dnn_lr/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:15:40
# INFO:tensorflow:Saving dict for global step 10000: average_loss = 4817504000.0, global_step = 10000, label/mean = 204546.2, loss = 604507540000.0, prediction/mean = 203506.73, rmse = 69408.24
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: ./trained_model/dnn_lr/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 36.677
# INFO:tensorflow:loss = 587683270000.0, step = 10001 (2.727 sec)
# INFO:tensorflow:global_step/sec: 153.461
# INFO:tensorflow:loss = 824736740000.0, step = 10101 (0.651 sec)
# INFO:tensorflow:global_step/sec: 143.158
# INFO:tensorflow:loss = 842051600000.0, step = 10201 (0.699 sec)
# INFO:tensorflow:global_step/sec: 145.659
# INFO:tensorflow:loss = 587795500000.0, step = 10301 (0.686 sec)
# INFO:tensorflow:global_step/sec: 147.233
# INFO:tensorflow:loss = 610069100000.0, step = 10401 (0.679 sec)
# INFO:tensorflow:global_step/sec: 140.679
# INFO:tensorflow:loss = 376512050000.0, step = 10501 (0.714 sec)
# INFO:tensorflow:global_step/sec: 143.711
# INFO:tensorflow:loss = 347261700000.0, step = 10601 (0.694 sec)
# INFO:tensorflow:global_step/sec: 151.588
# INFO:tensorflow:loss = 490118840000.0, step = 10701 (0.658 sec)
# INFO:tensorflow:global_step/sec: 149.723
# INFO:tensorflow:loss = 382174600000.0, step = 10801 (0.672 sec)
# INFO:tensorflow:global_step/sec: 142.341
# INFO:tensorflow:loss = 563686740000.0, step = 10901 (0.698 sec)
# INFO:tensorflow:global_step/sec: 143.098
# INFO:tensorflow:loss = 1185533000000.0, step = 11001 (0.704 sec)
# INFO:tensorflow:global_step/sec: 143.327
# INFO:tensorflow:loss = 653134800000.0, step = 11101 (0.695 sec)
# INFO:tensorflow:global_step/sec: 135.2
# INFO:tensorflow:loss = 532714780000.0, step = 11201 (0.738 sec)
# INFO:tensorflow:global_step/sec: 134.432
# INFO:tensorflow:loss = 453978300000.0, step = 11301 (0.743 sec)
# INFO:tensorflow:global_step/sec: 155.013
# INFO:tensorflow:loss = 491054700000.0, step = 11401 (0.645 sec)
# INFO:tensorflow:global_step/sec: 152.854
# INFO:tensorflow:loss = 853982600000.0, step = 11501 (0.657 sec)
# INFO:tensorflow:global_step/sec: 147.127
# INFO:tensorflow:loss = 729505100000.0, step = 11601 (0.677 sec)
# INFO:tensorflow:global_step/sec: 151.236
# INFO:tensorflow:loss = 601293650000.0, step = 11701 (0.661 sec)
# INFO:tensorflow:global_step/sec: 151.393
# INFO:tensorflow:loss = 903900360000.0, step = 11801 (0.661 sec)
# INFO:tensorflow:global_step/sec: 147.129
# INFO:tensorflow:loss = 1080976500000.0, step = 11901 (0.679 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into ./trained_model/dnn_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:15:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/dnn_lr/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:15:57
# INFO:tensorflow:Saving dict for global step 12000: average_loss = 4878557000.0, global_step = 12000, label/mean = 204546.2, loss = 612168560000.0, prediction/mean = 216352.97, rmse = 69846.67
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: ./trained_model/dnn_lr/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 32.2394
# INFO:tensorflow:loss = 577445950000.0, step = 12001 (3.102 sec)
# INFO:tensorflow:global_step/sec: 109.683
# INFO:tensorflow:loss = 465063050000.0, step = 12101 (0.915 sec)
# INFO:tensorflow:global_step/sec: 143.514
# INFO:tensorflow:loss = 489234700000.0, step = 12201 (0.694 sec)
# INFO:tensorflow:global_step/sec: 126.098
# INFO:tensorflow:loss = 264983480000.0, step = 12301 (0.792 sec)
# INFO:tensorflow:global_step/sec: 138.286
# INFO:tensorflow:loss = 452314140000.0, step = 12401 (0.724 sec)
# INFO:tensorflow:global_step/sec: 144.507
# INFO:tensorflow:loss = 444352300000.0, step = 12501 (0.693 sec)
# INFO:tensorflow:global_step/sec: 148.947
# INFO:tensorflow:loss = 736902500000.0, step = 12601 (0.672 sec)
# INFO:tensorflow:global_step/sec: 148.661
# INFO:tensorflow:loss = 878307600000.0, step = 12701 (0.670 sec)
# INFO:tensorflow:global_step/sec: 145.404
# INFO:tensorflow:loss = 673037000000.0, step = 12801 (0.688 sec)
# INFO:tensorflow:global_step/sec: 145.866
# INFO:tensorflow:loss = 529818260000.0, step = 12901 (0.687 sec)
# INFO:tensorflow:global_step/sec: 147.257
# INFO:tensorflow:loss = 700949700000.0, step = 13001 (0.680 sec)
# INFO:tensorflow:global_step/sec: 148.702
# INFO:tensorflow:loss = 416865880000.0, step = 13101 (0.670 sec)
# INFO:tensorflow:global_step/sec: 125.772
# INFO:tensorflow:loss = 795385600000.0, step = 13201 (0.796 sec)
# INFO:tensorflow:global_step/sec: 141.04
# INFO:tensorflow:loss = 406293200000.0, step = 13301 (0.711 sec)
# INFO:tensorflow:global_step/sec: 145.138
# INFO:tensorflow:loss = 728502300000.0, step = 13401 (0.686 sec)
# INFO:tensorflow:global_step/sec: 152.071
# INFO:tensorflow:loss = 599200760000.0, step = 13501 (0.658 sec)
# INFO:tensorflow:global_step/sec: 145.447
# INFO:tensorflow:loss = 941998340000.0, step = 13601 (0.687 sec)
# INFO:tensorflow:global_step/sec: 119.261
# INFO:tensorflow:loss = 535324600000.0, step = 13701 (0.841 sec)
# INFO:tensorflow:global_step/sec: 141.793
# INFO:tensorflow:loss = 463323330000.0, step = 13801 (0.703 sec)
# INFO:tensorflow:global_step/sec: 144.068
# INFO:tensorflow:loss = 288174770000.0, step = 13901 (0.695 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into ./trained_model/dnn_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:16:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/dnn_lr/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:16:13
# INFO:tensorflow:Saving dict for global step 14000: average_loss = 4613782500.0, global_step = 14000, label/mean = 204546.2, loss = 578944300000.0, prediction/mean = 205739.52, rmse = 67924.83
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: ./trained_model/dnn_lr/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 37.9849
# INFO:tensorflow:loss = 460227350000.0, step = 14001 (2.632 sec)
# INFO:tensorflow:global_step/sec: 146.048
# INFO:tensorflow:loss = 428001170000.0, step = 14101 (0.685 sec)
# INFO:tensorflow:global_step/sec: 149.73
# INFO:tensorflow:loss = 537520540000.0, step = 14201 (0.668 sec)
# INFO:tensorflow:global_step/sec: 147.255
# INFO:tensorflow:loss = 965116950000.0, step = 14301 (0.682 sec)
# INFO:tensorflow:global_step/sec: 153.52
# INFO:tensorflow:loss = 859474170000.0, step = 14401 (0.650 sec)
# INFO:tensorflow:global_step/sec: 141.809
# INFO:tensorflow:loss = 610369140000.0, step = 14501 (0.702 sec)
# INFO:tensorflow:global_step/sec: 168.704
# INFO:tensorflow:loss = 353168460000.0, step = 14601 (0.593 sec)
# INFO:tensorflow:global_step/sec: 167.493
# INFO:tensorflow:loss = 394584330000.0, step = 14701 (0.597 sec)
# INFO:tensorflow:global_step/sec: 165.693
# INFO:tensorflow:loss = 381706400000.0, step = 14801 (0.604 sec)
# INFO:tensorflow:global_step/sec: 163.066
# INFO:tensorflow:loss = 872958660000.0, step = 14901 (0.614 sec)
# INFO:tensorflow:global_step/sec: 163.267
# INFO:tensorflow:loss = 410773950000.0, step = 15001 (0.614 sec)
# INFO:tensorflow:global_step/sec: 161.212
# INFO:tensorflow:loss = 746765600000.0, step = 15101 (0.619 sec)
# INFO:tensorflow:global_step/sec: 166.82
# INFO:tensorflow:loss = 736669140000.0, step = 15201 (0.599 sec)
# INFO:tensorflow:global_step/sec: 154.375
# INFO:tensorflow:loss = 761794660000.0, step = 15301 (0.648 sec)
# INFO:tensorflow:global_step/sec: 166.246
# INFO:tensorflow:loss = 662874900000.0, step = 15401 (0.601 sec)
# INFO:tensorflow:global_step/sec: 166.737
# INFO:tensorflow:loss = 323109650000.0, step = 15501 (0.604 sec)
# INFO:tensorflow:global_step/sec: 165.207
# INFO:tensorflow:loss = 276601770000.0, step = 15601 (0.601 sec)
# INFO:tensorflow:global_step/sec: 158.018
# INFO:tensorflow:loss = 327065300000.0, step = 15701 (0.633 sec)
# INFO:tensorflow:global_step/sec: 161.015
# INFO:tensorflow:loss = 341298220000.0, step = 15801 (0.621 sec)
# INFO:tensorflow:global_step/sec: 159.811
# INFO:tensorflow:loss = 781794150000.0, step = 15901 (0.627 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into ./trained_model/dnn_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:16:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/dnn_lr/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:16:27
# INFO:tensorflow:Saving dict for global step 16000: average_loss = 5438632400.0, global_step = 16000, label/mean = 204546.2, loss = 682447670000.0, prediction/mean = 230623.16, rmse = 73747.086
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: ./trained_model/dnn_lr/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 41.0683
# INFO:tensorflow:loss = 1216518000000.0, step = 16001 (2.434 sec)
# INFO:tensorflow:global_step/sec: 161.628
# INFO:tensorflow:loss = 1378226000000.0, step = 16101 (0.621 sec)
# INFO:tensorflow:global_step/sec: 162.328
# INFO:tensorflow:loss = 519979070000.0, step = 16201 (0.612 sec)
# INFO:tensorflow:global_step/sec: 162.431
# INFO:tensorflow:loss = 290476000000.0, step = 16301 (0.620 sec)
# INFO:tensorflow:global_step/sec: 160.193
# INFO:tensorflow:loss = 557447800000.0, step = 16401 (0.621 sec)
# INFO:tensorflow:global_step/sec: 164.624
# INFO:tensorflow:loss = 425471180000.0, step = 16501 (0.607 sec)
# INFO:tensorflow:global_step/sec: 165.178
# INFO:tensorflow:loss = 728584700000.0, step = 16601 (0.605 sec)
# INFO:tensorflow:global_step/sec: 160.668
# INFO:tensorflow:loss = 720512100000.0, step = 16701 (0.623 sec)
# INFO:tensorflow:global_step/sec: 160.966
# INFO:tensorflow:loss = 486801800000.0, step = 16801 (0.621 sec)
# INFO:tensorflow:global_step/sec: 162.011
# INFO:tensorflow:loss = 634660100000.0, step = 16901 (0.617 sec)
# INFO:tensorflow:global_step/sec: 174.123
# INFO:tensorflow:loss = 746067850000.0, step = 17001 (0.574 sec)
# INFO:tensorflow:global_step/sec: 176.733
# INFO:tensorflow:loss = 669505160000.0, step = 17101 (0.566 sec)
# INFO:tensorflow:global_step/sec: 171.03
# INFO:tensorflow:loss = 525799820000.0, step = 17201 (0.588 sec)
# INFO:tensorflow:global_step/sec: 166.026
# INFO:tensorflow:loss = 208409990000.0, step = 17301 (0.599 sec)
# INFO:tensorflow:global_step/sec: 167.14
# INFO:tensorflow:loss = 439429960000.0, step = 17401 (0.598 sec)
# INFO:tensorflow:global_step/sec: 167.735
# INFO:tensorflow:loss = 252179580000.0, step = 17501 (0.596 sec)
# INFO:tensorflow:global_step/sec: 157.074
# INFO:tensorflow:loss = 828160900000.0, step = 17601 (0.637 sec)
# INFO:tensorflow:global_step/sec: 164.798
# INFO:tensorflow:loss = 935713400000.0, step = 17701 (0.607 sec)
# INFO:tensorflow:global_step/sec: 178.711
# INFO:tensorflow:loss = 1028776070000.0, step = 17801 (0.560 sec)
# INFO:tensorflow:global_step/sec: 102.127
# INFO:tensorflow:loss = 694336950000.0, step = 17901 (0.979 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into ./trained_model/dnn_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:16:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/dnn_lr/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:16:41
# INFO:tensorflow:Saving dict for global step 18000: average_loss = 4659262000.0, global_step = 18000, label/mean = 204546.2, loss = 584651050000.0, prediction/mean = 195303.67, rmse = 68258.79
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: ./trained_model/dnn_lr/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 42.1981
# INFO:tensorflow:loss = 718524900000.0, step = 18001 (2.369 sec)
# INFO:tensorflow:global_step/sec: 159.706
# INFO:tensorflow:loss = 418778580000.0, step = 18101 (0.630 sec)
# INFO:tensorflow:global_step/sec: 156.844
# INFO:tensorflow:loss = 409170350000.0, step = 18201 (0.634 sec)
# INFO:tensorflow:global_step/sec: 161.879
# INFO:tensorflow:loss = 864357100000.0, step = 18301 (0.616 sec)
# INFO:tensorflow:global_step/sec: 164.757
# INFO:tensorflow:loss = 527342500000.0, step = 18401 (0.607 sec)
# INFO:tensorflow:global_step/sec: 167.21
# INFO:tensorflow:loss = 580661500000.0, step = 18501 (0.598 sec)
# INFO:tensorflow:global_step/sec: 158.187
# INFO:tensorflow:loss = 618228300000.0, step = 18601 (0.636 sec)
# INFO:tensorflow:global_step/sec: 164.52
# INFO:tensorflow:loss = 815723050000.0, step = 18701 (0.608 sec)
# INFO:tensorflow:global_step/sec: 167.263
# INFO:tensorflow:loss = 506373960000.0, step = 18801 (0.595 sec)
# INFO:tensorflow:global_step/sec: 161.154
# INFO:tensorflow:loss = 429848170000.0, step = 18901 (0.621 sec)
# INFO:tensorflow:global_step/sec: 154.09
# INFO:tensorflow:loss = 356277600000.0, step = 19001 (0.648 sec)
# INFO:tensorflow:global_step/sec: 161.017
# INFO:tensorflow:loss = 375343020000.0, step = 19101 (0.621 sec)
# INFO:tensorflow:global_step/sec: 161.872
# INFO:tensorflow:loss = 409912020000.0, step = 19201 (0.618 sec)
# INFO:tensorflow:global_step/sec: 162.853
# INFO:tensorflow:loss = 847005500000.0, step = 19301 (0.614 sec)
# INFO:tensorflow:global_step/sec: 163.251
# INFO:tensorflow:loss = 833803400000.0, step = 19401 (0.613 sec)
# INFO:tensorflow:global_step/sec: 163.187
# INFO:tensorflow:loss = 681247100000.0, step = 19501 (0.612 sec)
# INFO:tensorflow:global_step/sec: 165.068
# INFO:tensorflow:loss = 350205000000.0, step = 19601 (0.606 sec)
# INFO:tensorflow:global_step/sec: 159.916
# INFO:tensorflow:loss = 661616700000.0, step = 19701 (0.626 sec)
# INFO:tensorflow:global_step/sec: 159.469
# INFO:tensorflow:loss = 434895200000.0, step = 19801 (0.632 sec)
# INFO:tensorflow:global_step/sec: 154.583
# INFO:tensorflow:loss = 788118240000.0, step = 19901 (0.642 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./trained_model/dnn_lr/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-02-23:16:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/dnn_lr/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-02-23:16:56
# INFO:tensorflow:Saving dict for global step 20000: average_loss = 4795153400.0, global_step = 20000, label/mean = 204546.2, loss = 601702900000.0, prediction/mean = 184853.48, rmse = 69247.05
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./trained_model/dnn_lr/model.ckpt-20000
# INFO:tensorflow:Loss for final step: 465166200000.0.
# CPU times: user 9min 46s, sys: 5min 26s, total: 15min 12s
# Wall time: 10min 34s

# %% [markdown]
#  ## Plan
#
#  3. Establish LinearRegressor performance w/o feature engineering.
#  4. Beat it with feature engineering

# %%
if len(TensorBoard.list())>0:
  [TensorBoard().stop(pid)for pid in TensorBoard.list()['pid']]
else: print('No TensorBoard instances to stop')
