# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.set_style("whitegrid")

# %%
prob = np.arange(0, 1.0, 0.001)
odds = prob / (1-prob)
logits = np.log(odds)

f, (ax1, ax2, ax3) = plt.subplots(1, 3)
ax1.plot(prob, logits)
ax1.set_xlabel('Probability')
ax1.set_ylabel('Logit')
#ax1.set_title('L vs. P(Y)')

ax2.plot(logits, prob)
ax2.set_xlabel('Logit')
ax2.set_ylabel('Probability')
#ax2.set_title('P(Y) vs. L')

ax3.plot(odds, logits)
ax3.set_xlabel('Odds')
ax3.set_ylabel('Logit')
#ax3.set_title('L vs. odds')

plt.tight_layout()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:3: RuntimeWarning:
#
# divide by zero encountered in log

# %%
logits[len(logits)/2]
# Out:
# 0.0

# %%
x=len(logits)-50
print 'prob={} logit={}'.format(prob[x], logits[x])
x=len(logits)-5
print 'prob={} logit={}'.format(prob[x], logits[x])
x=len(logits)-1
print 'prob={} logit={}'.format(prob[x], logits[x])
# Out:
# prob=0.95 logit=2.94443897917
# prob=0.995 logit=5.29330482472
# prob=0.999 logit=6.90675477865
